# %%
import sys
sys.path.append('/Users/Micpr/Documents/Magdalen&Oxford/Engineering/Year 3/B1 Engineering Computation/Scientific coding/b1-coding-practical-mt24')
import uuv_mission.control as ctrl

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['c:\\Users\\Micpr\\Documents\\Magdalen&Oxford\\Engineering\\Year 3\\B1 Engineering Computation\\Scientific coding\\b1-coding-practical-mt24\\notebooks', 'C:\\Users\\Micpr\\Documents\\Magdalen&Oxford\\Engineering\\Year 3\\B1 Engineering Computation\\Scientific coding\\b1-coding-practical-mt24:', 'c:\\Users\\Micpr\\Anaconda\\python311.zip', 'c:\\Users\\Micpr\\Anaconda\\DLLs', 'c:\\Users\\Micpr\\Anaconda\\Lib', 'c:\\Users\\Micpr\\Anaconda', '', 'c:\\Users\\Micpr\\Anaconda\\Lib\\site-packages', 'c:\\Users\\Micpr\\Anaconda\\Lib\\site-packages\\win32', 'c:\\Users\\Micpr\\Anaconda\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\Micpr\\Anaconda\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
import sys
sys.path.append('/Users/Micpr/Documents/Magdalen&Oxford/Engineering/Year 3/B1 Engineering Computation/Scientific coding/b1-coding-practical-mt24')
from uuv_mission.control import Controller
from uuv_mission.dynamic import Submarine, ClosedLoop, Mission

sub = Submarine()
controller = Controller() 

closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("C:/Users/Micpr/Documents/Magdalen&Oxford/Engineering/Year 3/B1 Engineering Computation/Scientific coding/b1-coding-practical-mt24/data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
